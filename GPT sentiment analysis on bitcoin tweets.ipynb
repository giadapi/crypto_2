# %%
import pandas as pd

# %%
raw_data = pd.read_csv('16-03-23_to_08-04-23.csv')

# %%
test_data = raw_data[:100]
test_data
# Out:
#                      datetime         username  \
# 0   2023-03-16 00:09:38+00:00        Suzu20181
# 1   2023-03-16 00:09:32+00:00    IAmBitcoinBot
# 2   2023-03-16 00:09:26+00:00    The_Ring_Lord
# 3   2023-03-16 00:09:23+00:00      altcoinxbtc
# 4   2023-03-16 00:09:16+00:00  LivePriceCrypto
# ..                        ...              ...
# 95  2023-03-16 00:00:47+00:00       omelet_btc
# 96  2023-03-16 00:00:45+00:00   JumpLineAlerts
# 97  2023-03-16 00:00:44+00:00   JumpLineAlerts
# 98  2023-03-16 00:00:44+00:00   JumpLineAlerts
# 99  2023-03-16 00:00:44+00:00   JumpLineAlerts
#
#                                                  text
# 0               ＃BTC ＃Bitcoin https://t.co/3Nmdv7uWvv
# 1       Current #Bitcoin Price is $24399 #BTC #Crypto
# 2   @Dennis_Porter_ @elonmusk Elon is blinded by h...
# 3   @thecryptoc0up1e Excellent work congratulation...
# 4   #Bitcoin Fear and Greed index\n\nCurrent #BTC ...
# ..                                                ...
# ...

# %%
import openai

# Set your OpenAI API key
openai.api_key = "[YOUR API KEY]"

# Define a function to classify the sentiment of a given tweet using GPT-3
def classify_sentiment(tweet):
    prompt = "Perform sentiment analysis classification on this tweet " + tweet + "\nPositive, Negative, Neutral"
    response = openai.Completion.create(
        model="text-davinci-003",
        prompt = prompt,
        temperature=0,
        max_tokens=10,
        top_p=1.0,
        frequency_penalty=0.5,
        presence_penalty=0.0)
    
    sentiment = response.choices[0].text.strip()
    return sentiment

# Read in your CSV file of tweets
# import csv

# with open('tweets.csv', newline='') as csvfile:
#     reader = csv.reader(csvfile)
#     for row in reader:
#         tweet = row[0]
#         sentiment = classify_sentiment(tweet)
#         print(tweet + " - " + sentiment)

# %%
tweet = 'Bossing up be feeling so good it’s like you wake up happy every day knowing you a step closer to what you aiming for #Bitcoin 🕸️#OVL'
classify_sentiment(tweet)
# Out:
# 'Positive'

# %%
test_data['sentiment'] = test_data['text'].apply(classify_sentiment)
# Out:
# /var/folders/dn/rwn91pwx3q9c4zbfkf6rfb6h0000gn/T/ipykernel_15955/4177615065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['sentiment'] = test_data['text'].apply(classify_sentiment)

# %%
test_data.head()
# Out:
#                     datetime         username  \
# 0  2023-03-16 00:09:38+00:00        Suzu20181
# 1  2023-03-16 00:09:32+00:00    IAmBitcoinBot
# 2  2023-03-16 00:09:26+00:00    The_Ring_Lord
# 3  2023-03-16 00:09:23+00:00      altcoinxbtc
# 4  2023-03-16 00:09:16+00:00  LivePriceCrypto
#
#                                                 text sentiment senti§ment
# 0              ＃BTC ＃Bitcoin https://t.co/3Nmdv7uWvv   Neutral    Neutral
# 1      Current #Bitcoin Price is $24399 #BTC #Crypto  Positive    Neutral
# 2  @Dennis_Porter_ @elonmusk Elon is blinded by h...  Negative    Neutral
# 3  @thecryptoc0up1e Excellent work congratulation...  Positive    Neutral
# 4  #Bitcoin Fear and Greed index\n\nCurrent #BTC ...   Neutral    Neutral

# %%
for i in range(len(test_data)):
    print(test_data['text'][i])
    print(test_data['sentiment'][i])
    print('\n ___________')
# Out:
# ＃BTC ＃Bitcoin https://t.co/3Nmdv7uWvv
# Neutral
#
#  ___________
# Current #Bitcoin Price is $24399 #BTC #Crypto
# Positive
#
#  ___________
# @Dennis_Porter_ @elonmusk Elon is blinded by his ego when it comes to #Bitcoin. He got it right the first time when he backed Bitcoin, then decided he wanted his own crypto which is #Doge-shit.
# Negative
#
#  ___________
# @thecryptoc0up1e Excellent work congratulations #BITCOIN #BTC
# Positive
#
#  ___________
# #Bitcoin Fear and Greed index
#
# Current #BTC price is 24288 $
#
# #Crypto #FearAndGreed
#
# (6/13)
# 474180 https://t.co/gfCaMliSgc
# Neutral
#
#  ___________
# Here’s how the metaverse will evolve 🫣
# #metaverse #cryptoworld #Meta #cryptocurrency #blockchain #crypto #nft #web3 #ethereum #ETH #bitcoin #BTC #nftcommunity #nftcollector https://t.co/zDnhtq6v59
#
#
#  ___________
# 10/
# For similar threads on #Bitcoin #crypto  #DeFi #NFT #web3 :
#
# Follow 👉 @CoinWealthly
#
# ...
